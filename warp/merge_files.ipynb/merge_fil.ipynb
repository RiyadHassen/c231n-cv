# %%
import pandas as pd

# Load the two CSV files
file1 = 'file2.csv'  # The file where you want to update the score
file2 = 'file1.csv'  # The file from where you will get the score

# Read CSV files into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# # Set the 'name' column as the index for easier matching (optional but useful if 'name' is unique)
# df2.set_index('name', inplace=True)

# # Update the 'score' in df1 based on the matching 'name' column
# df1['score'] = df1['name'].map(df2['score'])

# # Save the updated df1 back to a new CSV file
# df1.to_csv('updated_file.csv', index=False)

# print("File saved as 'updated_file.csv'")

# %%
def process_csv(filename):
    # open the file, its a text file utf-8
    example_file = open(filename, encoding="utf-8")
    # prepare it for reading as a CSV object
    example_reader = csv.reader(example_file)
    # use the built-in list function to convert this into a list of lists
    example_data = list(example_reader)
    # close the file to tidy up our workspace
    example_file.close()
    # return the list of lists
    
    return example_data

# %%
gradebook_data = process_csv("file1.csv")
#gradebook_data = gradebook_data[2:]
#gradebook_data[0][3], gradebook_data[0][4][-6:]

# %%
df1 = pd.read_csv(file1)

# %%
df1
# Out:
#               name      id     sis_id              section  section_id  \
# 0     AADIT SINGAL  573703  UW104J732  COMP SCI 300:LEC003      548262
# 1     AAGAM SOGANI  547397  UW104M962  COMP SCI 300:LEC004      548265
# 2    AAKASH PANERU  535194  UW100F174  COMP SCI 300:LEC002      535186
# 3       AARAV DANI  559993  UW104S382  COMP SCI 300:LEC001      535184
# 4       AARON CHEN  559391  UW104J001  COMP SCI 300:LEC002      535186
# ..             ...     ...        ...                  ...         ...
# 844    Zackery LIU  546463  UW104I884  COMP SCI 300:LEC002      535186
# 845     Zhan Cheng  579055  UW107R645  COMP SCI 300:LEC003      548262
# 846  ZHIXUAN LIANG  575760  UW106D976  COMP SCI 300:LEC003      548262
# 847     ZHIYUAN LI  565395  UW097E264  COMP SCI 300:LEC002      535186
# 848     ZUBIN SOOD  566143  UW107O496  COMP SCI 300:LEC001      535184
#
#     section_sis_id                submitted  attempt  \
# 0       1252:36253  2024-09-08 04:57:00 UTC        1
# ...

# %%
df2
# Out:
#                    Student        ID SIS User ID  \
# 0          Points Possible       NaN         NaN
# 1          ABDALAH, KHADER  502479.0   UW972L280
# 2    ABIPROJO, CHRISTOPHER  546971.0   UW104J468
# 3           ABRAHAM, SAHEL  573722.0   UW104F904
# 4              ADLER, Greg  419013.0   UW924H928
# ..                     ...       ...         ...
# 867          ZHUANG, ETHAN  580030.0   UW107G534
# 868              ZI, Yurun  545801.0   UW104B724
# 869          Zitouni, Semo  565430.0   UW981A667
# 870         ZONG, XUANPING  567839.0   UW107D180
# 871           Zou, Jeffery  591495.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                           KABDALAH@WISC.EDU
# 2                           ABIPROJO@WISC.EDU
# 3                         SJABRAHAM2@WISC.EDU
# 4                           GMADLER2@WISC.EDU
# ..                                        ...
# ...

# %%
df2['new_score'] = 0

# %%
count =0
# go throw the gradebook
#using iterrows() gives a copy of the dataframe it doesnot updat the actual dataframe
for index, row in df2.iterrows():
   
    if index==0:
        continue;
    # find similarity in assigment
    #df1 is assigment
    val1 =  df1[df1['sis_id']==row['SIS User ID']]
    # go through each similarity in the assigment
    
    for index2, row2 in val1.iterrows():
        #row['P01 Pre-Assignment Quiz (2458526)'] = row2['score']
        #use df.loc to update the actual value
        if row['P01 Pre-Assignment Quiz (2458526)'] != row2['score']:
            #row['new_score'] = row2['score']
            df2.loc[index,'new_score'] = row2['score']
            count+=1
        else:
            #row['new_score'] = row['P01 Pre-Assignment Quiz (2458526)']
            df2.loc[index,'new_score'] = row['P01 Pre-Assignment Quiz (2458526)']
    #print(row['new_score'])
        
print(count)
# Out:
# /var/folders/ms/9m1pz5xd2531d1mscylcs7vr0000gn/T/ipykernel_99800/3212088890.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.loc[index,'new_score'] = row['P01 Pre-Assignment Quiz (2458526)']
# 302

# %%
df2
# Out:
#                    Student        ID SIS User ID  \
# 0          Points Possible       NaN         NaN
# 1          ABDALAH, KHADER  502479.0   UW972L280
# 2    ABIPROJO, CHRISTOPHER  546971.0   UW104J468
# 3           ABRAHAM, SAHEL  573722.0   UW104F904
# 4              ADLER, Greg  419013.0   UW924H928
# ..                     ...       ...         ...
# 867          ZHUANG, ETHAN  580030.0   UW107G534
# 868              ZI, Yurun  545801.0   UW104B724
# 869          Zitouni, Semo  565430.0   UW981A667
# 870         ZONG, XUANPING  567839.0   UW107D180
# 871           Zou, Jeffery  591495.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                           KABDALAH@WISC.EDU
# 2                           ABIPROJO@WISC.EDU
# 3                         SJABRAHAM2@WISC.EDU
# 4                           GMADLER2@WISC.EDU
# ..                                        ...
# ...

# %%
df2.to_csv('updated_file.csv', index=False)
